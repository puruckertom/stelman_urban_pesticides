# %%
import jn_setup
from tools.paths import *
from simulation_procedure import model
import pandas as pd, pyabc, hydroeval
# Out:
# To activate test mode, run 'inp_path = set_inp_path('test')'.
# To activate run mode, run 'inp_path = set_inp_path('run')'.
# C:\Users\jstelman\Git\stelman_urban_pesticides\master_test\NPlesantCreek.inp

# %%
# see if error check for min/max problem worked
model({'NImperv': 0.0179,
 'NPerv': 0.3951,
 'SImperv': 1.363,
 'SPerv': 4.442,
 'PctZero': 15.2,
 'MaxRate': 8.273,
 'MinRate': 9.266,
 'Decay': 6.26,
 'DryTime': 8.0,
 'Por': 0.465,
 'FC': 0.361,
 'WP': 0.119,
 'Ksat': 1.719,
 'Rough': 0.0194,
 'Kdecay': 0.045,
 'BCoeff2': 1.584,
 'WCoeff2': 0.203,
 'kd': 5333.21,
 'aer_aq': 272.0,
 'aer_aq_temp': 22.96,
 'anae_aq': 255.0,
 'anae_aq_temp': 23.76,
 'photo': 404.98,
 'rflat': 40.0,
 'hydro': 106.3,
 'sol': 0.48,
 'benthic_depth': 0.884,
 'porosity': 0.71,
 'bulk_density': 1.61,
 'froc2': 0.02,
 'doc2': 27.62,
 'bnmas': 1.094,
 'sused': 51.269,
 'chl': 0.984,
 'froc1': 0.113,
 'doc1': 0.64})
# Out:
# Folder  6c5a9c65  created
#
# Folder  6c5a9c65 outfall_31_26  created
#
# Folder  6c5a9c65 outfall_31_28  created
#
# Folder  6c5a9c65 outfall_31_29  created
#
# Folder  6c5a9c65 outfall_31_35  created
#
# Folder  6c5a9c65 outfall_31_36  created
#
# Folder  6c5a9c65 outfall_31_38  created
#
# Folder  6c5a9c65 outfall_31_42  created
# {'2009-02-13_26': 0.0,
#  '2009-02-13_28': 0.0,
#  '2009-02-13_29': 0.0,
#  '2009-04-07_28': 90603000000.0,
#  '2009-04-07_29': 67443000000.0,
#  '2009-04-08_26': 289590000.0,
#  '2009-04-13_26': 32424999.999999996,
#  '2009-04-13_28': 36889000.0,
#  '2009-04-13_29': 7738200000.0,
#  '2009-05-01_26': 9963800000.0,
#  '2009-05-01_28': 9152800000.0,
#  '2009-05-01_29': 24222000000.0,
#  '2009-08-28_26': 129740000.00000001,
#  '2009-08-28_28': 85945000.0,
#  '2009-08-28_29': 168950000.0,
#  '2009-10-12_26': 264350000.00000003,
#  '2009-10-12_28': 410540000.0,
#  '2009-10-12_29': 161760000.0,
#  '2009-10-13_26': 13486000000.0,
# ...

# %%
# see if error check for min/max problem worked
model({'NImperv': 0.0179,
 'NPerv': 0.3951,
 'SImperv': 1.363,
 'SPerv': 4.442,
 'PctZero': 15.2,
 'MaxRate': 9.273,
 'MinRate': 8.266,
 'Decay': 6.26,
 'DryTime': 8.0,
 'Por': 0.465,
 'FC': 0.231,
 'WP': 0.319,
 'Ksat': 1.719,
 'Rough': 0.0194,
 'Kdecay': 0.045,
 'BCoeff2': 1.584,
 'WCoeff2': 0.203,
 'kd': 5333.21,
 'aer_aq': 272.0,
 'aer_aq_temp': 22.96,
 'anae_aq': 255.0,
 'anae_aq_temp': 23.76,
 'photo': 404.98,
 'rflat': 40.0,
 'hydro': 106.3,
 'sol': 0.48,
 'benthic_depth': 0.884,
 'porosity': 0.71,
 'bulk_density': 1.61,
 'froc2': 0.02,
 'doc2': 27.62,
 'bnmas': 1.094,
 'sused': 51.269,
 'chl': 0.984,
 'froc1': 0.113,
 'doc1': 0.64})
# Out:
# Folder  d4aadeff  created
#
# Folder  d4aadeff outfall_31_26  created
#
# Folder  d4aadeff outfall_31_28  created
#
# Folder  d4aadeff outfall_31_29  created
#
# Folder  d4aadeff outfall_31_35  created
#
# Folder  d4aadeff outfall_31_36  created
#
# Folder  d4aadeff outfall_31_38  created
#
# Folder  d4aadeff outfall_31_42  created
# {'2009-02-13_26': 0.0,
#  '2009-02-13_28': 0.0,
#  '2009-02-13_29': 0.0,
#  '2009-04-07_28': 90603000000.0,
#  '2009-04-07_29': 67443000000.0,
#  '2009-04-08_26': 289590000.0,
#  '2009-04-13_26': 32424999.999999996,
#  '2009-04-13_28': 36889000.0,
#  '2009-04-13_29': 7738200000.0,
#  '2009-05-01_26': 9963800000.0,
#  '2009-05-01_28': 9152800000.0,
#  '2009-05-01_29': 24222000000.0,
#  '2009-08-28_26': 129740000.00000001,
#  '2009-08-28_28': 85945000.0,
#  '2009-08-28_29': 168950000.0,
#  '2009-10-12_26': 264350000.00000003,
#  '2009-10-12_28': 410540000.0,
#  '2009-10-12_29': 161760000.0,
#  '2009-10-13_26': 13486000000.0,
# ...

# %%
# see if error check for min/max problem worked
model({'NImperv': 0.0179,
 'NPerv': 0.3951,
 'SImperv': 1.363,
 'SPerv': 4.442,
 'PctZero': 15.2,
 'MaxRate': 9.273,
 'MinRate': 8.266,
 'Decay': 6.26,
 'DryTime': 8.0,
 'Por': 0.465,
 'FC': 0.361,
 'WP': 0.119,
 'Ksat': 1.719,
 'Rough': 0.0194,
 'Kdecay': 0.045,
 'BCoeff2': 1.584,
 'WCoeff2': 0.203,
 'kd': 5333.21,
 'aer_aq': 272.0,
 'aer_aq_temp': 22.96,
 'anae_aq': 255.0,
 'anae_aq_temp': 23.76,
 'photo': 404.98,
 'rflat': 40.0,
 'hydro': 106.3,
 'sol': 0.48,
 'benthic_depth': 0.884,
 'porosity': 0.71,
 'bulk_density': 1.61,
 'froc2': 0.02,
 'doc2': 27.62,
 'bnmas': 1.094,
 'sused': 51.269,
 'chl': 0.984,
 'froc1': 0.113,
 'doc1': 0.64})
# Out:
# Folder  a527a161  created
#
# Folder  a527a161 outfall_31_26  created
#
# Folder  a527a161 outfall_31_28  created
#
# Folder  a527a161 outfall_31_29  created
#
# Folder  a527a161 outfall_31_35  created
#
# Folder  a527a161 outfall_31_36  created
#
# Folder  a527a161 outfall_31_38  created
#
# Folder  a527a161 outfall_31_42  created
# {'2009-02-13_26': 0.0,
#  '2009-02-13_28': 0.0,
#  '2009-02-13_29': 0.0,
#  '2009-04-07_28': 90603000000.0,
#  '2009-04-07_29': 67443000000.0,
#  '2009-04-08_26': 289590000.0,
#  '2009-04-13_26': 32424999.999999996,
#  '2009-04-13_28': 36889000.0,
#  '2009-04-13_29': 7738200000.0,
#  '2009-05-01_26': 9963800000.0,
#  '2009-05-01_28': 9152800000.0,
#  '2009-05-01_29': 24222000000.0,
#  '2009-08-28_26': 129740000.00000001,
#  '2009-08-28_28': 85945000.0,
#  '2009-08-28_29': 168950000.0,
#  '2009-10-12_26': 264350000.00000003,
#  '2009-10-12_28': 410540000.0,
#  '2009-10-12_29': 161760000.0,
#  '2009-10-13_26': 13486000000.0,
# ...
